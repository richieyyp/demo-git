# %% [markdown]
# ## Exercise 10 : Data Visualization II
#
# This assignment uses data from the [UC Irvine Machine Learning Repository](http://archive.ics.uci.edu/ml/), a popular repository for machine learning datasets. In particular, we will be using the "Individual household electric power consumption Data Set" which can be downloaded from the link given below:
#
# **Dataset:** [Electric power consumption](https://d396qusza40orc.cloudfront.net/exdata%2Fdata%2Fhousehold_power_consumption.zip) [20Mb]
#
# **Description:** Measurements of electric power consumption in one household with a one-minute sampling rate over a period of almost 4 years. Different electrical quantities and some sub-metering values are available.
#
# The following descriptions of the 9 variables in the dataset are taken from the UCI web site:
#
# 1. **Date:** Date in format dd/mm/yyyy
# 2. **Time:** time in format hh:mm:ss
# 3. **Global_active_power:** household global minute-averaged active power (in kilowatt)
# 4. **Global_reactive_power:** household global minute-averaged reactive power (in kilowatt)
# 5. **Voltage:** minute-averaged voltage (in volt)
# 6. **Global_intensity:** household global minute-averaged current intensity (in ampere)
# 7. **Sub_metering_1:** energy sub-metering No. 1 (in watt-hour of active energy). It corresponds to the kitchen, containing mainly a dishwasher, an oven and a microwave (hot plates are not electric but gas powered).
# 8. **Sub_metering_2:** energy sub-metering No. 2 (in watt-hour of active energy). It corresponds to the laundry room, containing a washing-machine, a tumble-drier, a refrigerator and a light.
# 9. **Sub_metering_3:** energy sub-metering No. 3 (in watt-hour of active energy). It corresponds to an electric water-heater and an air-conditioner.
#
# ### Loading the data
#
# When loading the dataset, please consider the following:
#
# The dataset has 2,075,259 rows and 9 columns.
#
# For this exercise, we will only be using data from the dates 2007-02-01 and 2007-02-02. One alternative is to read the data from just those dates rather than reading in the entire dataset and subsetting to those dates.
#
# ### Making Plots
#
# Our overall goal here is simply to examine how household energy usage varies over a 2-day period in February, 2007. Your task is to reconstruct the following plots below, all of which were constructed using the matplotlib plotting system.
#
# For each plot you should
#
# - Construct the plot and save it to a PNG file with a width of 480 pixels and a height of 480 pixels.
#
# - Name each of the plot files as plot1.png, plot2.png, etc.
#
# - Add the PNG file and assignment2.ipynb file to your git repository
#
# - When you are finished with the assignment, push your git repository to GitHub so that the GitHub version of your repository is up to date. There should be four PNG files and one assignment2.ipynb files.
#
# - The four plots that you will need to construct are shown below.

# %%
#your code here
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#read the data

data=pd.read_csv('../../data/week04/household_power_consumption.txt',sep=';',na_values='?')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075259 entries, 0 to 2075258
# Data columns (total 9 columns):
# Date                     object
# Time                     object
# Global_active_power      float64
# Global_reactive_power    float64
# Voltage                  float64
# Global_intensity         float64
# Sub_metering_1           float64
# Sub_metering_2           float64
# Sub_metering_3           float64
# dtypes: float64(7), object(2)
# memory usage: 142.5+ MB

# %%
data1 = data [((data['Date']=='1/2/2007' )| (data['Date']=='2/2/2007'))]
data1['Date'] = pd.to_datetime(data1['Date'] )
data1.head(10)
# data1.info()
# Out:
# C:\Users\CPGAN\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#             Date      Time  Global_active_power  Global_reactive_power  \
# 66636 2007-01-02  00:00:00                0.326                  0.128
# 66637 2007-01-02  00:01:00                0.326                  0.130
# 66638 2007-01-02  00:02:00                0.324                  0.132
# 66639 2007-01-02  00:03:00                0.324                  0.134
# 66640 2007-01-02  00:04:00                0.322                  0.130
# 66641 2007-01-02  00:05:00                0.320                  0.126
# 66642 2007-01-02  00:06:00                0.320                  0.126
# ...

# %%
# plot1



 
fig, ax = plt.subplots(nrows=1, ncols=1,figsize=(8,3), dpi=100)

ax.hist(data1['Global_active_power'], 8, histtype='bar', color='red')
# axes.legend(prop={'size': 10})
ax.set_title('Global Active Power')

ax.set_ylabel('Frequency')
ax.set_xlabel('Global Active Power (kilowatts)')

ax.set_ylim([0,1600])
ax.set_xlim([0,6])

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

fig.savefig("plot1.png",figsize=(4.8,4.8), dpi=400)

# plt.show()

# %%
#plot1

# %% [markdown]
# <img src ='images/plot1.png'>
#
# Plot 1

# %%
#plot2

# data2 = data [((data['Date']=='1/2/2007' )| (data['Date']=='2/2/2007'))]

# data2 = data2.sort_values(['Date','Time'], ascending=True)

# data2['datetime'] = data2['Date'].map(str) +' '+ data2['Time']
# data2['datetime'] = pd.to_datetime(data2['datetime'], format='%d/%m/%Y %H:%M:%S' )

# fig, ax2 = plt.subplots(figsize=(12,3), dpi=100)
# ax2.plot(data2['datetime'], data2['Global_active_power'], 'b')

# ax2.set_ylabel('Global Active Power (kilowatts)')
# ax2.set_title('Global Active Power for 01-02-2007 - 02-02-2007');


# ax2.spines['right'].set_color('none')
# ax2.spines['top'].set_color('none')

# fig.savefig("plot2.png", dpi=400)

data1 = data1.sort_values(['Date','Time'], ascending=True)

data1['datetime'] = data1['Date'].map(str) +' '+ data1['Time']
data1['datetime'] = pd.to_datetime(data2['datetime'], format='%d/%m/%Y %H:%M:%S' )

fig, ax = plt.subplots(figsize=(12,3), dpi=100)
ax.plot(data1['datetime'], data1['Global_active_power'], 'b')

ax.set_ylabel('Global Active Power (kilowatts)')
ax.set_title('Global Active Power for 01-02-2007 - 02-02-2007')


ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

fig.savefig("plot2.png",figsize=(4.8,4.8), dpi=400)

# %%
#plot2

# %% [markdown]
# <img src='images/plot2.png'>
#
# Plot 2

# %%
#plot3

# data3 = data [((data['Date']=='1/2/2007' )| (data['Date']=='2/2/2007'))]

# data3 = data3.sort_values(['Date','Time'], ascending=True)

# data3['datetime'] = data3['Date'].map(str) +' '+ data3['Time']
# data3['datetime'] = pd.to_datetime(data3['datetime'], format='%d/%m/%Y %H:%M:%S' )

# fig, ax3 = plt.subplots(figsize=(12,4), dpi=100)
# ax3.plot(data3['datetime'], data3['Sub_metering_1'], 'black')
# ax3.plot(data3['datetime'], data3['Sub_metering_2'], 'red')
# ax3.plot(data3['datetime'], data3['Sub_metering_3'], 'blue')

# ax3.set_ylabel('Global Active Power (kilowatts)')
# ax3.set_ylim([0,40])

# ax3.set_title('Energy Sub Metering');
# ax3.legend(('Sub Metering 1','Sub Metering 2','Sub Metering 3'));


# ax3.spines['right'].set_color('none')
# ax3.spines['top'].set_color('none')

# fig.savefig("plot3.png", dpi=400)


fig, ax = plt.subplots(figsize=(12,4), dpi=100)
ax.plot(data1['datetime'], data1['Sub_metering_1'], 'black')
ax.plot(data1['datetime'], data1['Sub_metering_2'], 'red')
ax.plot(data1['datetime'], data1['Sub_metering_3'], 'blue')

ax.set_ylabel('Global Active Power (kilowatts)')
ax.set_ylim([0,40])

ax.set_title('Energy Sub Metering')
ax.legend(('Sub Metering 1','Sub Metering 2','Sub Metering 3'))


ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

fig.savefig("plot3.png",figsize=(4.8,4.8), dpi=400)

# %%
#plot3

# %% [markdown]
# <img src ='images/plot3.png'>
#
# Plot 3

# %%
#plot 4

fig, axes = plt.subplots(nrows=2, ncols=2,figsize=(12,5), dpi=100)
ax0, ax1, ax2, ax3 = axes.flatten()

ax0.plot(data1['datetime'], data1['Global_active_power'], 'b')
ax0.set_title('Global Active');

ax1.plot(data1['datetime'], data1['Voltage'], 'b')
ax1.set_title('Voltage');


ax2.plot(data1['datetime'], data1['Sub_metering_1'], 'black')
ax2.plot(data1['datetime'], data1['Sub_metering_2'], 'red')
ax2.plot(data1['datetime'], data1['Sub_metering_3'], 'blue')
ax2.set_ylim([0,40])
ax2.set_title('Energy Sub Metering');
ax2.legend(('Sub Metering 1','Sub Metering 2','Sub Metering 3'))

ax3.plot(data1['datetime'], data1['Global_reactive_power'], 'b')
ax3.set_title('Global Reactive Power');

fig.tight_layout()

fig.savefig("plot4.png",figsize=(4.8,4.8), dpi=400)

# %%
#plot 4

# %% [markdown]
# <img src='images/plot4.png'>
#
# Plot4
